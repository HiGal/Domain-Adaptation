# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
from utils import *
from torch import optim
from torch.functional import F
# from torch.utils import tensorboard

# %%
np.random.seed(1337)
torch.manual_seed(1337)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
BATCH_SIZE = 128
lr = 2e-4
EPOCHS = 100
N = 4
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

# %%
source_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5, 0.5), (0.5,0.5, 0.5))
])
target_transform = transforms.Compose([
    transforms.Resize((32,32)),
    transforms.Grayscale(num_output_channels=3), 
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5, 0.5), (0.5,0.5, 0.5))
])

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator,self).__init__()
        self.generator = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=64, kernel_size=5, padding=2), #28
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1), #13
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=5, padding = 2), #9
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1), #4
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=5, padding = 2), #128x1
            nn.BatchNorm2d(128),
            nn.ReLU()
        )
        
        self.linear = nn.Sequential(
            nn.Linear(8192,3072),
            nn.BatchNorm1d(3072),
            nn.ReLU(True),
            nn.Dropout()
        )
    
    def forward(self, x):
        out = self.generator(x)
        out = out.view(out.size(0), 8192)
        out = self.linear(out)
        return out

# %%
class Classifier(nn.Module):
    def __init__(self):
        super(Classifier, self).__init__()
        self.classifier = nn.Sequential(
            nn.Linear(3072,2048),
            nn.BatchNorm1d(2048),
            nn.ReLU(True),
            nn.Linear(2048,10)
        )

    def forward(self, x):
        out = self.classifier(x)
        return out

# %% [markdown]
# ### Xavier Weights Initialization

# %%
def init_weights(m):
    if type(m) == nn.Conv2d:
        nn.init.xavier_normal(m.weight)
    if type(m) == nn.Linear:
        nn.init.xavier_normal(m.weight)

# %%
G = Generator().apply(init_weights).to(device)
C1 = Classifier().apply(init_weights).to(device)
C2 = Classifier().apply(init_weights).to(device)

# %% [markdown]
# ### Defining optimizers

# %%
optimizer_G = optim.Adam(G.parameters(),lr=lr, weight_decay=5e-4)
optimizer_C1 = optim.Adam(C1.parameters(), lr=lr,weight_decay=5e-4)
optimizer_C2 = optim.Adam(C2.parameters(), lr=lr,weight_decay=5e-4)
log_interval = 100
criterion = nn.CrossEntropyLoss()

# %%
writter = tensorboard.SummaryWriter()

# %%
def discrepancy(out1, out2):
    return torch.mean(torch.abs(F.softmax(out1)- F.softmax(out2)))

def zero_grad():
    optimizer_G.zero_grad()
    optimizer_C1.zero_grad()
    optimizer_C2.zero_grad()

# %% [markdown]
# ### Train / Test

# %%
def train():
    G.train()
    C1.train()
    C2.train()
    
    len_dataloader = min(len(source_train), len(target_train))
    data_zip = enumerate(zip(source_train, target_train))
    for batch_idx, ((img_s, labels),(img_t,_)) in data_zip:
        img_s = img_s.to(device)
        labels = labels.to(device)
        img_t = img_t.to(device)
        
        zero_grad()
        feature_s = G(img_s)
        out_s1 = C1(feature_s)
        out_s2 = C2(feature_s)
        
        loss_s1 = criterion(out_s1, labels)
        loss_s2 = criterion(out_s2, labels)
        loss_s = loss_s1 + loss_s2
        
        loss_s.backward()
        optimizer_G.step()
        optimizer_C1.step()
        optimizer_C2.step()
        
        zero_grad()
        feature_s = G(img_s)
        out_s1 = C1(feature_s)
        out_s2 = C2(feature_s)
        feature_t = G(img_t)
        out_t1 = C1(feature_t)
        out_t2 = C2(feature_t)
        
        loss_s1 = criterion(out_s1, labels)
        loss_s2 = criterion(out_s2, labels)
        loss_s = loss_s1 + loss_s2
        loss_discrepancy = discrepancy(out_t1, out_t2)
        loss = loss_s - loss_discrepancy
        
        
        loss.backward()
        optimizer_C1.step()
        optimizer_C2.step()
        
        zero_grad()
        
        
        for i in range(N):
            feature_t = G(img_t)
            out_t1 = C1(feature_t)
            out_t2 = C2(feature_t)
            loss_discrepancy = discrepancy(out_t1, out_t2)
            loss_discrepancy.backward()
            optimizer_G.step()
            zero_grad()
        
        if (batch_idx+1) % log_interval == 0:
            print("Epoch: {}/{} [{}/{}]: C1 Source Loss ={:.5f}, C2 Source Loss={:.5f}, Discrepancy Loss={:.5f}"
                 .format(epoch+1, EPOCHS, batch_idx + 1, len_dataloader, loss_s1.item(), loss_s2.item(),loss_discrepancy.item()))
        
        if batch_idx == 20:
            writter.add_scalar('Train/Loss C1 Source',loss_s1.item(), epoch)
            writter.add_scalar('Train/Loss C2 Source',loss_s2.item(), epoch)
            writter.add_scalar('Train/Loss Discrepancy',loss_discrepancy.item(), epoch)

# %%
def test(max):
    G.eval()
    C1.eval()
    C2.eval()
    test_loss = 0
    correct = 0
    for (imgs, labels) in target_val:
        imgs = imgs.to(device)
        labels = labels.to(device)
        features = G(imgs)
        output1 = C1(features)
        output2 = C2(features)
        output_of_two = output1 + output2
        pred_of_two = output_of_two.data.max(1)[1]
        correct += pred_of_two.eq(labels.data).cpu().sum()
    
    size = len(target_val.dataset)
    acc_mnist = 100. * correct / size
    if acc_mnist > max:
        max = acc_mnist
        torch.save(G.state_dict(),'Weights/MCD/Generator_epoch{}_{:.2f}.pth'.format(epoch,acc_mnist))
        torch.save(C1.state_dict(),'Weights/MCD/C1_epoch{}_{:.2f}.pth'.format(epoch,acc_mnist))
        torch.save(C2.state_dict(),'Weights/MCD/C2_epoch{}_{:.2f}.pth'.format(epoch,acc_mnist))
    
    correct = 0
    for (imgs, labels) in source_train:
        imgs = imgs.to(device)
        labels = labels.to(device)
        features = G(imgs)
        output1 = C1(features)
        output2 = C2(features)
        output_of_two = output1 + output2
        pred_of_two = output_of_two.data.max(1)[1]
        correct += pred_of_two.eq(labels.data).cpu().sum()
    
    size = len(source_train.dataset)
    acc_svhn_train = 100. * correct / size
    
    correct = 0
    for (imgs, labels) in source_val:
        imgs = imgs.to(device)
        labels = labels.to(device)
        features = G(imgs)
        output1 = C1(features)
        output2 = C2(features)
        output_of_two = output1 + output2
        pred_of_two = output_of_two.data.max(1)[1]
        correct += pred_of_two.eq(labels.data).cpu().sum()
    
    size = len(source_val.dataset)
    acc_svhn_test = 100. * correct / size
        
    print(
        '\nTest: Accuracy on MNIST: {:.0f}% Accuracy on SVHN train: {:.0f}% Accuracy on SVHN test: {:.0f}% \n'.format(
            acc_mnist, acc_svhn_train, acc_svhn_test))
    writter.add_scalar('Test/Accuracy MNIST Test', acc_mnist, epoch)
    writter.add_scalar('Test/Accuracy SVHN Train', acc_svhn_train, epoch)
    writter.add_scalar('Test/Accuracy SVHN Test', acc_svhn_test, epoch)
    writter.flush()
    return max

# %%
max = 0
for epoch in range(EPOCHS):
    train()
    max = test(max)
# Out:
# Epoch: 1/100 [100/469]: C1 Source Loss =0.42135, C2 Source Loss=0.41960, Discrepancy Loss=0.01512
# Epoch: 1/100 [200/469]: C1 Source Loss =0.30488, C2 Source Loss=0.30933, Discrepancy Loss=0.00883
# Epoch: 1/100 [300/469]: C1 Source Loss =0.39869, C2 Source Loss=0.38143, Discrepancy Loss=0.00825
# Epoch: 1/100 [400/469]: C1 Source Loss =0.47868, C2 Source Loss=0.47859, Discrepancy Loss=0.00660
#
# Test: Accuracy on MNIST: 76% Accuracy on SVHN train: 62% Accuracy on SVHN test: 61%
#
# Epoch: 2/100 [100/469]: C1 Source Loss =0.34077, C2 Source Loss=0.35216, Discrepancy Loss=0.00695
# Epoch: 2/100 [200/469]: C1 Source Loss =0.42092, C2 Source Loss=0.42545, Discrepancy Loss=0.00463
# Epoch: 2/100 [300/469]: C1 Source Loss =0.32008, C2 Source Loss=0.32773, Discrepancy Loss=0.00407
# Epoch: 2/100 [400/469]: C1 Source Loss =0.27736, C2 Source Loss=0.27654, Discrepancy Loss=0.00591
#
# Test: Accuracy on MNIST: 76% Accuracy on SVHN train: 69% Accuracy on SVHN test: 69%
#
# Epoch: 3/100 [100/469]: C1 Source Loss =0.25223, C2 Source Loss=0.25313, Discrepancy Loss=0.00421
# Epoch: 3/100 [200/469]: C1 Source Loss =0.40716, C2 Source Loss=0.39895, Discrepancy Loss=0.00418
# Epoch: 3/100 [300/469]: C1 Source Loss =0.19984, C2 Source Loss=0.20166, Discrepancy Loss=0.00496
# Epoch: 3/100 [400/469]: C1 Source Loss =0.34189, C2 Source Loss=0.34476, Discrepancy Loss=0.00347
#
# Test: Accuracy on MNIST: 78% Accuracy on SVHN train: 74% Accuracy on SVHN test: 72%
#
# Epoch: 4/100 [100/469]: C1 Source Loss =0.18336, C2 Source Loss=0.19196, Discrepancy Loss=0.00492
# Epoch: 4/100 [200/469]: C1 Source Loss =0.45117, C2 Source Loss=0.43085, Discrepancy Loss=0.00587
# Epoch: 4/100 [300/469]: C1 Source Loss =0.35559, C2 Source Loss=0.35485, Discrepancy Loss=0.00519
# Epoch: 4/100 [400/469]: C1 Source Loss =0.22932, C2 Source Loss=0.22971, Discrepancy Loss=0.00703
#
# Test: Accuracy on MNIST: 85% Accuracy on SVHN train: 77% Accuracy on SVHN test: 76%
#
# Epoch: 5/100 [100/469]: C1 Source Loss =0.13647, C2 Source Loss=0.13449, Discrepancy Loss=0.00500
# Epoch: 5/100 [200/469]: C1 Source Loss =0.15934, C2 Source Loss=0.15936, Discrepancy Loss=0.00576
# Epoch: 5/100 [300/469]: C1 Source Loss =0.22686, C2 Source Loss=0.22922, Discrepancy Loss=0.00536
# Epoch: 5/100 [400/469]: C1 Source Loss =0.29139, C2 Source Loss=0.29404, Discrepancy Loss=0.00536
#
# Test: Accuracy on MNIST: 88% Accuracy on SVHN train: 75% Accuracy on SVHN test: 74%
#
# Epoch: 6/100 [100/469]: C1 Source Loss =0.20025, C2 Source Loss=0.20098, Discrepancy Loss=0.00382
# Epoch: 6/100 [200/469]: C1 Source Loss =0.21115, C2 Source Loss=0.20628, Discrepancy Loss=0.00540
# Epoch: 6/100 [300/469]: C1 Source Loss =0.19961, C2 Source Loss=0.18861, Discrepancy Loss=0.00482
# Epoch: 6/100 [400/469]: C1 Source Loss =0.37676, C2 Source Loss=0.37524, Discrepancy Loss=0.00502
#
# Test: Accuracy on MNIST: 87% Accuracy on SVHN train: 82% Accuracy on SVHN test: 81%
#
# Epoch: 7/100 [100/469]: C1 Source Loss =0.14153, C2 Source Loss=0.13259, Discrepancy Loss=0.00526
# Epoch: 7/100 [200/469]: C1 Source Loss =0.19503, C2 Source Loss=0.19259, Discrepancy Loss=0.00525
# Epoch: 7/100 [300/469]: C1 Source Loss =0.28660, C2 Source Loss=0.28693, Discrepancy Loss=0.00488
# Epoch: 7/100 [400/469]: C1 Source Loss =0.13784, C2 Source Loss=0.13843, Discrepancy Loss=0.00592
#
# Test: Accuracy on MNIST: 87% Accuracy on SVHN train: 79% Accuracy on SVHN test: 77%
#
# Epoch: 8/100 [100/469]: C1 Source Loss =0.18114, C2 Source Loss=0.17356, Discrepancy Loss=0.00491
# Epoch: 8/100 [200/469]: C1 Source Loss =0.20371, C2 Source Loss=0.20033, Discrepancy Loss=0.00480
# Epoch: 8/100 [300/469]: C1 Source Loss =0.20992, C2 Source Loss=0.21403, Discrepancy Loss=0.00453
# Epoch: 8/100 [400/469]: C1 Source Loss =0.34066, C2 Source Loss=0.33543, Discrepancy Loss=0.00511
#
# Test: Accuracy on MNIST: 87% Accuracy on SVHN train: 82% Accuracy on SVHN test: 79%
#
# Epoch: 9/100 [100/469]: C1 Source Loss =0.16058, C2 Source Loss=0.16632, Discrepancy Loss=0.00354
# Epoch: 9/100 [200/469]: C1 Source Loss =0.17182, C2 Source Loss=0.16545, Discrepancy Loss=0.00353
# Epoch: 9/100 [300/469]: C1 Source Loss =0.22766, C2 Source Loss=0.22292, Discrepancy Loss=0.00356
# Epoch: 9/100 [400/469]: C1 Source Loss =0.33343, C2 Source Loss=0.33387, Discrepancy Loss=0.00231
#
# Test: Accuracy on MNIST: 89% Accuracy on SVHN train: 84% Accuracy on SVHN test: 83%
#
# Epoch: 10/100 [100/469]: C1 Source Loss =0.11311, C2 Source Loss=0.11546, Discrepancy Loss=0.00304
# Epoch: 10/100 [200/469]: C1 Source Loss =0.15491, C2 Source Loss=0.16294, Discrepancy Loss=0.00409
# Epoch: 10/100 [300/469]: C1 Source Loss =0.20741, C2 Source Loss=0.20440, Discrepancy Loss=0.00391
# Epoch: 10/100 [400/469]: C1 Source Loss =0.19865, C2 Source Loss=0.19493, Discrepancy Loss=0.00426
#
# Test: Accuracy on MNIST: 89% Accuracy on SVHN train: 84% Accuracy on SVHN test: 83%
#
# Epoch: 11/100 [100/469]: C1 Source Loss =0.21245, C2 Source Loss=0.21041, Discrepancy Loss=0.00275
# Epoch: 11/100 [200/469]: C1 Source Loss =0.19432, C2 Source Loss=0.19376, Discrepancy Loss=0.00282
# Epoch: 11/100 [300/469]: C1 Source Loss =0.18165, C2 Source Loss=0.18882, Discrepancy Loss=0.00333
# Epoch: 11/100 [400/469]: C1 Source Loss =0.21174, C2 Source Loss=0.21292, Discrepancy Loss=0.00306
#
# Test: Accuracy on MNIST: 89% Accuracy on SVHN train: 82% Accuracy on SVHN test: 81%
#
# Epoch: 12/100 [100/469]: C1 Source Loss =0.14353, C2 Source Loss=0.13992, Discrepancy Loss=0.00320
# Epoch: 12/100 [200/469]: C1 Source Loss =0.12294, C2 Source Loss=0.12354, Discrepancy Loss=0.00317
# Epoch: 12/100 [300/469]: C1 Source Loss =0.20516, C2 Source Loss=0.20883, Discrepancy Loss=0.00344
# Epoch: 12/100 [400/469]: C1 Source Loss =0.21842, C2 Source Loss=0.22314, Discrepancy Loss=0.00294
#
# Test: Accuracy on MNIST: 88% Accuracy on SVHN train: 82% Accuracy on SVHN test: 81%
#
# Epoch: 13/100 [100/469]: C1 Source Loss =0.14830, C2 Source Loss=0.14743, Discrepancy Loss=0.00311
# Epoch: 13/100 [200/469]: C1 Source Loss =0.11889, C2 Source Loss=0.11078, Discrepancy Loss=0.00375
# Epoch: 13/100 [300/469]: C1 Source Loss =0.15833, C2 Source Loss=0.15335, Discrepancy Loss=0.00257
# Epoch: 13/100 [400/469]: C1 Source Loss =0.11836, C2 Source Loss=0.12390, Discrepancy Loss=0.00474
#
# Test: Accuracy on MNIST: 90% Accuracy on SVHN train: 86% Accuracy on SVHN test: 85%
#
# Epoch: 14/100 [100/469]: C1 Source Loss =0.29416, C2 Source Loss=0.28381, Discrepancy Loss=0.00277
# Epoch: 14/100 [200/469]: C1 Source Loss =0.16497, C2 Source Loss=0.16702, Discrepancy Loss=0.00229
# Epoch: 14/100 [300/469]: C1 Source Loss =0.13396, C2 Source Loss=0.12998, Discrepancy Loss=0.00250
# Epoch: 14/100 [400/469]: C1 Source Loss =0.18641, C2 Source Loss=0.18707, Discrepancy Loss=0.00258
#
# Test: Accuracy on MNIST: 89% Accuracy on SVHN train: 87% Accuracy on SVHN test: 86%
#
# Epoch: 15/100 [100/469]: C1 Source Loss =0.16009, C2 Source Loss=0.16239, Discrepancy Loss=0.00294
# Epoch: 15/100 [200/469]: C1 Source Loss =0.14766, C2 Source Loss=0.15186, Discrepancy Loss=0.00169
# Epoch: 15/100 [300/469]: C1 Source Loss =0.15910, C2 Source Loss=0.15648, Discrepancy Loss=0.00245
# Epoch: 15/100 [400/469]: C1 Source Loss =0.11536, C2 Source Loss=0.11303, Discrepancy Loss=0.00320
#
# Test: Accuracy on MNIST: 89% Accuracy on SVHN train: 83% Accuracy on SVHN test: 82%
#
# Epoch: 16/100 [100/469]: C1 Source Loss =0.10462, C2 Source Loss=0.10655, Discrepancy Loss=0.00232
# Epoch: 16/100 [200/469]: C1 Source Loss =0.08296, C2 Source Loss=0.08199, Discrepancy Loss=0.00242
# Epoch: 16/100 [300/469]: C1 Source Loss =0.18165, C2 Source Loss=0.18596, Discrepancy Loss=0.00259
# Epoch: 16/100 [400/469]: C1 Source Loss =0.22340, C2 Source Loss=0.22432, Discrepancy Loss=0.00236
#
# Test: Accuracy on MNIST: 89% Accuracy on SVHN train: 87% Accuracy on SVHN test: 86%
#
# Epoch: 17/100 [100/469]: C1 Source Loss =0.17524, C2 Source Loss=0.17522, Discrepancy Loss=0.00237
# Epoch: 17/100 [200/469]: C1 Source Loss =0.15732, C2 Source Loss=0.15832, Discrepancy Loss=0.00410
# Epoch: 17/100 [300/469]: C1 Source Loss =0.16020, C2 Source Loss=0.17076, Discrepancy Loss=0.00288
# Epoch: 17/100 [400/469]: C1 Source Loss =0.18662, C2 Source Loss=0.18029, Discrepancy Loss=0.00177
#
# Test: Accuracy on MNIST: 87% Accuracy on SVHN train: 88% Accuracy on SVHN test: 86%
#
# Epoch: 18/100 [100/469]: C1 Source Loss =0.06982, C2 Source Loss=0.06840, Discrepancy Loss=0.00273
# Epoch: 18/100 [200/469]: C1 Source Loss =0.13282, C2 Source Loss=0.12358, Discrepancy Loss=0.00259
# Epoch: 18/100 [300/469]: C1 Source Loss =0.17983, C2 Source Loss=0.18150, Discrepancy Loss=0.00284
# Epoch: 18/100 [400/469]: C1 Source Loss =0.16443, C2 Source Loss=0.16620, Discrepancy Loss=0.00262
#
# Test: Accuracy on MNIST: 90% Accuracy on SVHN train: 82% Accuracy on SVHN test: 82%
#
# Epoch: 19/100 [100/469]: C1 Source Loss =0.10623, C2 Source Loss=0.10712, Discrepancy Loss=0.00252
# Epoch: 19/100 [200/469]: C1 Source Loss =0.16233, C2 Source Loss=0.16318, Discrepancy Loss=0.00249
# Epoch: 19/100 [300/469]: C1 Source Loss =0.09809, C2 Source Loss=0.09512, Discrepancy Loss=0.00165
# Epoch: 19/100 [400/469]: C1 Source Loss =0.11885, C2 Source Loss=0.11322, Discrepancy Loss=0.00259
#
# Test: Accuracy on MNIST: 91% Accuracy on SVHN train: 82% Accuracy on SVHN test: 82%
#
# Epoch: 20/100 [100/469]: C1 Source Loss =0.13236, C2 Source Loss=0.13219, Discrepancy Loss=0.00181
# Epoch: 20/100 [200/469]: C1 Source Loss =0.19425, C2 Source Loss=0.18945, Discrepancy Loss=0.00198
# Epoch: 20/100 [300/469]: C1 Source Loss =0.14686, C2 Source Loss=0.13728, Discrepancy Loss=0.00241
# Epoch: 20/100 [400/469]: C1 Source Loss =0.10027, C2 Source Loss=0.09673, Discrepancy Loss=0.00208
#
# Test: Accuracy on MNIST: 91% Accuracy on SVHN train: 83% Accuracy on SVHN test: 82%
#
# Epoch: 21/100 [100/469]: C1 Source Loss =0.21325, C2 Source Loss=0.21089, Discrepancy Loss=0.00170
# Epoch: 21/100 [200/469]: C1 Source Loss =0.14203, C2 Source Loss=0.14475, Discrepancy Loss=0.00332
# Epoch: 21/100 [300/469]: C1 Source Loss =0.06882, C2 Source Loss=0.07146, Discrepancy Loss=0.00258
# Epoch: 21/100 [400/469]: C1 Source Loss =0.11869, C2 Source Loss=0.12149, Discrepancy Loss=0.00263
#
# Test: Accuracy on MNIST: 91% Accuracy on SVHN train: 90% Accuracy on SVHN test: 87%
#
# Epoch: 22/100 [100/469]: C1 Source Loss =0.03289, C2 Source Loss=0.03328, Discrepancy Loss=0.00144
# Epoch: 22/100 [200/469]: C1 Source Loss =0.14255, C2 Source Loss=0.14298, Discrepancy Loss=0.00276
# Epoch: 22/100 [300/469]: C1 Source Loss =0.12020, C2 Source Loss=0.12352, Discrepancy Loss=0.00234
# Epoch: 22/100 [400/469]: C1 Source Loss =0.15595, C2 Source Loss=0.15128, Discrepancy Loss=0.00167
#
# Test: Accuracy on MNIST: 92% Accuracy on SVHN train: 89% Accuracy on SVHN test: 87%
#
# Epoch: 23/100 [100/469]: C1 Source Loss =0.19537, C2 Source Loss=0.19793, Discrepancy Loss=0.00185
# Epoch: 23/100 [200/469]: C1 Source Loss =0.06015, C2 Source Loss=0.05956, Discrepancy Loss=0.00209
# Epoch: 23/100 [300/469]: C1 Source Loss =0.11229, C2 Source Loss=0.11193, Discrepancy Loss=0.00158
# Epoch: 23/100 [400/469]: C1 Source Loss =0.06425, C2 Source Loss=0.06210, Discrepancy Loss=0.00230
#
# Test: Accuracy on MNIST: 91% Accuracy on SVHN train: 81% Accuracy on SVHN test: 80%
#
# Epoch: 24/100 [100/469]: C1 Source Loss =0.21557, C2 Source Loss=0.21700, Discrepancy Loss=0.00142
# Epoch: 24/100 [200/469]: C1 Source Loss =0.10244, C2 Source Loss=0.10008, Discrepancy Loss=0.00267
# Epoch: 24/100 [300/469]: C1 Source Loss =0.06693, C2 Source Loss=0.06673, Discrepancy Loss=0.00111
# Epoch: 24/100 [400/469]: C1 Source Loss =0.11809, C2 Source Loss=0.11164, Discrepancy Loss=0.00172
#
# Test: Accuracy on MNIST: 91% Accuracy on SVHN train: 86% Accuracy on SVHN test: 85%
#
# Epoch: 25/100 [100/469]: C1 Source Loss =0.06574, C2 Source Loss=0.06683, Discrepancy Loss=0.00158
# Epoch: 25/100 [200/469]: C1 Source Loss =0.14259, C2 Source Loss=0.14297, Discrepancy Loss=0.00167
# Epoch: 25/100 [300/469]: C1 Source Loss =0.09158, C2 Source Loss=0.09523, Discrepancy Loss=0.00167
# Epoch: 25/100 [400/469]: C1 Source Loss =0.05817, C2 Source Loss=0.05264, Discrepancy Loss=0.00112
#
# Test: Accuracy on MNIST: 93% Accuracy on SVHN train: 86% Accuracy on SVHN test: 85%
#
# Epoch: 26/100 [100/469]: C1 Source Loss =0.08258, C2 Source Loss=0.08181, Discrepancy Loss=0.00202
# Epoch: 26/100 [200/469]: C1 Source Loss =0.19935, C2 Source Loss=0.19784, Discrepancy Loss=0.00109
# Epoch: 26/100 [300/469]: C1 Source Loss =0.11175, C2 Source Loss=0.11634, Discrepancy Loss=0.00114
# Epoch: 26/100 [400/469]: C1 Source Loss =0.12779, C2 Source Loss=0.12903, Discrepancy Loss=0.00046
#
# Test: Accuracy on MNIST: 95% Accuracy on SVHN train: 88% Accuracy on SVHN test: 86%
#
# Epoch: 27/100 [100/469]: C1 Source Loss =0.06843, C2 Source Loss=0.07422, Discrepancy Loss=0.00169
# Epoch: 27/100 [200/469]: C1 Source Loss =0.08595, C2 Source Loss=0.08376, Discrepancy Loss=0.00165
# Epoch: 27/100 [300/469]: C1 Source Loss =0.19793, C2 Source Loss=0.19718, Discrepancy Loss=0.00107
# Epoch: 27/100 [400/469]: C1 Source Loss =0.08793, C2 Source Loss=0.08701, Discrepancy Loss=0.00100
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 88% Accuracy on SVHN test: 87%
#
# Epoch: 28/100 [100/469]: C1 Source Loss =0.12014, C2 Source Loss=0.12113, Discrepancy Loss=0.00122
# Epoch: 28/100 [200/469]: C1 Source Loss =0.08013, C2 Source Loss=0.08318, Discrepancy Loss=0.00227
# Epoch: 28/100 [300/469]: C1 Source Loss =0.12965, C2 Source Loss=0.12839, Discrepancy Loss=0.00189
# Epoch: 28/100 [400/469]: C1 Source Loss =0.09689, C2 Source Loss=0.09797, Discrepancy Loss=0.00127
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 89% Accuracy on SVHN test: 87%
#
# Epoch: 29/100 [100/469]: C1 Source Loss =0.10960, C2 Source Loss=0.10497, Discrepancy Loss=0.00162
# Epoch: 29/100 [200/469]: C1 Source Loss =0.22145, C2 Source Loss=0.22479, Discrepancy Loss=0.00160
# Epoch: 29/100 [300/469]: C1 Source Loss =0.09189, C2 Source Loss=0.09552, Discrepancy Loss=0.00092
# Epoch: 29/100 [400/469]: C1 Source Loss =0.17099, C2 Source Loss=0.16859, Discrepancy Loss=0.00238
#
# Test: Accuracy on MNIST: 95% Accuracy on SVHN train: 86% Accuracy on SVHN test: 85%
#
# Epoch: 30/100 [100/469]: C1 Source Loss =0.04036, C2 Source Loss=0.03883, Discrepancy Loss=0.00127
# Epoch: 30/100 [200/469]: C1 Source Loss =0.09209, C2 Source Loss=0.09478, Discrepancy Loss=0.00168
# Epoch: 30/100 [300/469]: C1 Source Loss =0.12616, C2 Source Loss=0.13123, Discrepancy Loss=0.00132
# Epoch: 30/100 [400/469]: C1 Source Loss =0.16171, C2 Source Loss=0.16374, Discrepancy Loss=0.00158
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 91% Accuracy on SVHN test: 89%
#
# Epoch: 31/100 [100/469]: C1 Source Loss =0.11398, C2 Source Loss=0.11412, Discrepancy Loss=0.00123
# Epoch: 31/100 [200/469]: C1 Source Loss =0.07818, C2 Source Loss=0.07732, Discrepancy Loss=0.00173
# Epoch: 31/100 [300/469]: C1 Source Loss =0.08233, C2 Source Loss=0.07636, Discrepancy Loss=0.00068
# Epoch: 31/100 [400/469]: C1 Source Loss =0.07390, C2 Source Loss=0.07555, Discrepancy Loss=0.00148
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 89% Accuracy on SVHN test: 88%
#
# Epoch: 32/100 [100/469]: C1 Source Loss =0.07469, C2 Source Loss=0.07359, Discrepancy Loss=0.00125
# Epoch: 32/100 [200/469]: C1 Source Loss =0.15448, C2 Source Loss=0.15323, Discrepancy Loss=0.00133
# Epoch: 32/100 [300/469]: C1 Source Loss =0.10245, C2 Source Loss=0.10556, Discrepancy Loss=0.00136
# Epoch: 32/100 [400/469]: C1 Source Loss =0.11921, C2 Source Loss=0.11835, Discrepancy Loss=0.00152
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 87% Accuracy on SVHN test: 85%
#
# Epoch: 33/100 [100/469]: C1 Source Loss =0.05987, C2 Source Loss=0.05970, Discrepancy Loss=0.00243
# Epoch: 33/100 [200/469]: C1 Source Loss =0.06724, C2 Source Loss=0.06688, Discrepancy Loss=0.00120
# Epoch: 33/100 [300/469]: C1 Source Loss =0.04526, C2 Source Loss=0.04580, Discrepancy Loss=0.00107
# Epoch: 33/100 [400/469]: C1 Source Loss =0.12750, C2 Source Loss=0.12711, Discrepancy Loss=0.00193
#
# Test: Accuracy on MNIST: 95% Accuracy on SVHN train: 90% Accuracy on SVHN test: 87%
#
# Epoch: 34/100 [100/469]: C1 Source Loss =0.13452, C2 Source Loss=0.13357, Discrepancy Loss=0.00174
# Epoch: 34/100 [200/469]: C1 Source Loss =0.09835, C2 Source Loss=0.09698, Discrepancy Loss=0.00120
# Epoch: 34/100 [300/469]: C1 Source Loss =0.10306, C2 Source Loss=0.10497, Discrepancy Loss=0.00097
# Epoch: 34/100 [400/469]: C1 Source Loss =0.07462, C2 Source Loss=0.07422, Discrepancy Loss=0.00173
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 90% Accuracy on SVHN test: 88%
#
# Epoch: 35/100 [100/469]: C1 Source Loss =0.04643, C2 Source Loss=0.04472, Discrepancy Loss=0.00188
# Epoch: 35/100 [200/469]: C1 Source Loss =0.08417, C2 Source Loss=0.09124, Discrepancy Loss=0.00201
# Epoch: 35/100 [300/469]: C1 Source Loss =0.07323, C2 Source Loss=0.07105, Discrepancy Loss=0.00132
# Epoch: 35/100 [400/469]: C1 Source Loss =0.07191, C2 Source Loss=0.07340, Discrepancy Loss=0.00083
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 89% Accuracy on SVHN test: 87%
#
# Epoch: 36/100 [100/469]: C1 Source Loss =0.14489, C2 Source Loss=0.14495, Discrepancy Loss=0.00076
# Epoch: 36/100 [200/469]: C1 Source Loss =0.02664, C2 Source Loss=0.02638, Discrepancy Loss=0.00140
# Epoch: 36/100 [300/469]: C1 Source Loss =0.15958, C2 Source Loss=0.15721, Discrepancy Loss=0.00155
# Epoch: 36/100 [400/469]: C1 Source Loss =0.06599, C2 Source Loss=0.06620, Discrepancy Loss=0.00094
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 90% Accuracy on SVHN test: 88%
#
# Epoch: 37/100 [100/469]: C1 Source Loss =0.05950, C2 Source Loss=0.05735, Discrepancy Loss=0.00178
# Epoch: 37/100 [200/469]: C1 Source Loss =0.09783, C2 Source Loss=0.09299, Discrepancy Loss=0.00178
# Epoch: 37/100 [300/469]: C1 Source Loss =0.11739, C2 Source Loss=0.11562, Discrepancy Loss=0.00218
# Epoch: 37/100 [400/469]: C1 Source Loss =0.04850, C2 Source Loss=0.04747, Discrepancy Loss=0.00105
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 89% Accuracy on SVHN test: 87%
#
# Epoch: 38/100 [100/469]: C1 Source Loss =0.03191, C2 Source Loss=0.03240, Discrepancy Loss=0.00104
# Epoch: 38/100 [200/469]: C1 Source Loss =0.07947, C2 Source Loss=0.07709, Discrepancy Loss=0.00161
# Epoch: 38/100 [300/469]: C1 Source Loss =0.06953, C2 Source Loss=0.06888, Discrepancy Loss=0.00239
# Epoch: 38/100 [400/469]: C1 Source Loss =0.13555, C2 Source Loss=0.13475, Discrepancy Loss=0.00069
#
# Test: Accuracy on MNIST: 95% Accuracy on SVHN train: 84% Accuracy on SVHN test: 82%
#
# Epoch: 39/100 [100/469]: C1 Source Loss =0.07083, C2 Source Loss=0.06966, Discrepancy Loss=0.00129
# Epoch: 39/100 [200/469]: C1 Source Loss =0.02338, C2 Source Loss=0.02360, Discrepancy Loss=0.00115
# Epoch: 39/100 [300/469]: C1 Source Loss =0.04662, C2 Source Loss=0.04912, Discrepancy Loss=0.00132
# Epoch: 39/100 [400/469]: C1 Source Loss =0.05454, C2 Source Loss=0.05860, Discrepancy Loss=0.00180
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 83% Accuracy on SVHN test: 82%
#
# Epoch: 40/100 [100/469]: C1 Source Loss =0.08398, C2 Source Loss=0.08098, Discrepancy Loss=0.00112
# Epoch: 40/100 [200/469]: C1 Source Loss =0.05999, C2 Source Loss=0.06087, Discrepancy Loss=0.00106
# Epoch: 40/100 [300/469]: C1 Source Loss =0.10495, C2 Source Loss=0.10999, Discrepancy Loss=0.00086
# Epoch: 40/100 [400/469]: C1 Source Loss =0.11815, C2 Source Loss=0.11427, Discrepancy Loss=0.00135
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 90% Accuracy on SVHN test: 87%
#
# Epoch: 41/100 [100/469]: C1 Source Loss =0.06986, C2 Source Loss=0.07215, Discrepancy Loss=0.00088
# Epoch: 41/100 [200/469]: C1 Source Loss =0.08712, C2 Source Loss=0.08366, Discrepancy Loss=0.00158
# Epoch: 41/100 [300/469]: C1 Source Loss =0.03374, C2 Source Loss=0.03739, Discrepancy Loss=0.00146
# Epoch: 41/100 [400/469]: C1 Source Loss =0.04753, C2 Source Loss=0.04884, Discrepancy Loss=0.00136
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 89% Accuracy on SVHN test: 87%
#
# Epoch: 42/100 [100/469]: C1 Source Loss =0.07305, C2 Source Loss=0.07519, Discrepancy Loss=0.00077
# Epoch: 42/100 [200/469]: C1 Source Loss =0.03524, C2 Source Loss=0.03465, Discrepancy Loss=0.00078
# Epoch: 42/100 [300/469]: C1 Source Loss =0.03739, C2 Source Loss=0.03845, Discrepancy Loss=0.00131
# Epoch: 42/100 [400/469]: C1 Source Loss =0.09938, C2 Source Loss=0.09684, Discrepancy Loss=0.00091
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 89% Accuracy on SVHN test: 86%
#
# Epoch: 43/100 [100/469]: C1 Source Loss =0.09822, C2 Source Loss=0.09889, Discrepancy Loss=0.00090
# Epoch: 43/100 [200/469]: C1 Source Loss =0.09364, C2 Source Loss=0.09124, Discrepancy Loss=0.00106
# Epoch: 43/100 [300/469]: C1 Source Loss =0.04312, C2 Source Loss=0.04468, Discrepancy Loss=0.00119
# Epoch: 43/100 [400/469]: C1 Source Loss =0.06500, C2 Source Loss=0.06623, Discrepancy Loss=0.00138
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 90% Accuracy on SVHN test: 88%
#
# Epoch: 44/100 [100/469]: C1 Source Loss =0.08448, C2 Source Loss=0.08643, Discrepancy Loss=0.00124
# Epoch: 44/100 [200/469]: C1 Source Loss =0.05200, C2 Source Loss=0.05122, Discrepancy Loss=0.00138
# Epoch: 44/100 [300/469]: C1 Source Loss =0.06685, C2 Source Loss=0.06825, Discrepancy Loss=0.00075
# Epoch: 44/100 [400/469]: C1 Source Loss =0.12887, C2 Source Loss=0.12917, Discrepancy Loss=0.00188
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 81% Accuracy on SVHN test: 81%
#
# Epoch: 45/100 [100/469]: C1 Source Loss =0.05052, C2 Source Loss=0.05184, Discrepancy Loss=0.00107
# Epoch: 45/100 [200/469]: C1 Source Loss =0.08643, C2 Source Loss=0.08381, Discrepancy Loss=0.00117
# Epoch: 45/100 [300/469]: C1 Source Loss =0.09411, C2 Source Loss=0.09601, Discrepancy Loss=0.00116
# Epoch: 45/100 [400/469]: C1 Source Loss =0.11083, C2 Source Loss=0.10978, Discrepancy Loss=0.00152
#
# Test: Accuracy on MNIST: 95% Accuracy on SVHN train: 82% Accuracy on SVHN test: 81%
#
# Epoch: 46/100 [100/469]: C1 Source Loss =0.05083, C2 Source Loss=0.05060, Discrepancy Loss=0.00154
# Epoch: 46/100 [200/469]: C1 Source Loss =0.03395, C2 Source Loss=0.03280, Discrepancy Loss=0.00208
# Epoch: 46/100 [300/469]: C1 Source Loss =0.03527, C2 Source Loss=0.03457, Discrepancy Loss=0.00066
# Epoch: 46/100 [400/469]: C1 Source Loss =0.10954, C2 Source Loss=0.10800, Discrepancy Loss=0.00087
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 88% Accuracy on SVHN test: 86%
#
# Epoch: 47/100 [100/469]: C1 Source Loss =0.16119, C2 Source Loss=0.15530, Discrepancy Loss=0.00083
# Epoch: 47/100 [200/469]: C1 Source Loss =0.12818, C2 Source Loss=0.13157, Discrepancy Loss=0.00217
# Epoch: 47/100 [300/469]: C1 Source Loss =0.04178, C2 Source Loss=0.04176, Discrepancy Loss=0.00123
# Epoch: 47/100 [400/469]: C1 Source Loss =0.03884, C2 Source Loss=0.03686, Discrepancy Loss=0.00132
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 87% Accuracy on SVHN test: 85%
#
# Epoch: 48/100 [100/469]: C1 Source Loss =0.10552, C2 Source Loss=0.10854, Discrepancy Loss=0.00127
# Epoch: 48/100 [200/469]: C1 Source Loss =0.03572, C2 Source Loss=0.03783, Discrepancy Loss=0.00117
# Epoch: 48/100 [300/469]: C1 Source Loss =0.02667, C2 Source Loss=0.02481, Discrepancy Loss=0.00155
# Epoch: 48/100 [400/469]: C1 Source Loss =0.03589, C2 Source Loss=0.03708, Discrepancy Loss=0.00097
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 88% Accuracy on SVHN test: 86%
#
# Epoch: 49/100 [100/469]: C1 Source Loss =0.02858, C2 Source Loss=0.02915, Discrepancy Loss=0.00153
# Epoch: 49/100 [200/469]: C1 Source Loss =0.08282, C2 Source Loss=0.08259, Discrepancy Loss=0.00088
# Epoch: 49/100 [300/469]: C1 Source Loss =0.05643, C2 Source Loss=0.05988, Discrepancy Loss=0.00139
# Epoch: 49/100 [400/469]: C1 Source Loss =0.08309, C2 Source Loss=0.08002, Discrepancy Loss=0.00111
#
# Test: Accuracy on MNIST: 95% Accuracy on SVHN train: 85% Accuracy on SVHN test: 84%
#
# Epoch: 50/100 [100/469]: C1 Source Loss =0.17355, C2 Source Loss=0.17489, Discrepancy Loss=0.00130
# Epoch: 50/100 [200/469]: C1 Source Loss =0.06598, C2 Source Loss=0.06219, Discrepancy Loss=0.00092
# Epoch: 50/100 [300/469]: C1 Source Loss =0.06220, C2 Source Loss=0.06462, Discrepancy Loss=0.00078
# Epoch: 50/100 [400/469]: C1 Source Loss =0.07399, C2 Source Loss=0.07028, Discrepancy Loss=0.00187
#
# Test: Accuracy on MNIST: 95% Accuracy on SVHN train: 88% Accuracy on SVHN test: 87%
#
# Epoch: 51/100 [100/469]: C1 Source Loss =0.12170, C2 Source Loss=0.11783, Discrepancy Loss=0.00170
# Epoch: 51/100 [200/469]: C1 Source Loss =0.05923, C2 Source Loss=0.05622, Discrepancy Loss=0.00130
# Epoch: 51/100 [300/469]: C1 Source Loss =0.03171, C2 Source Loss=0.03031, Discrepancy Loss=0.00156
# Epoch: 51/100 [400/469]: C1 Source Loss =0.09131, C2 Source Loss=0.08892, Discrepancy Loss=0.00100
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 89% Accuracy on SVHN test: 86%
#
# Epoch: 52/100 [100/469]: C1 Source Loss =0.04225, C2 Source Loss=0.04327, Discrepancy Loss=0.00073
# Epoch: 52/100 [200/469]: C1 Source Loss =0.13555, C2 Source Loss=0.13565, Discrepancy Loss=0.00167
# Epoch: 52/100 [300/469]: C1 Source Loss =0.10150, C2 Source Loss=0.10422, Discrepancy Loss=0.00136
# Epoch: 52/100 [400/469]: C1 Source Loss =0.07883, C2 Source Loss=0.08170, Discrepancy Loss=0.00192
#
# Test: Accuracy on MNIST: 95% Accuracy on SVHN train: 92% Accuracy on SVHN test: 88%
#
# Epoch: 53/100 [100/469]: C1 Source Loss =0.05012, C2 Source Loss=0.04802, Discrepancy Loss=0.00076
# Epoch: 53/100 [200/469]: C1 Source Loss =0.09895, C2 Source Loss=0.09697, Discrepancy Loss=0.00165
# Epoch: 53/100 [300/469]: C1 Source Loss =0.11427, C2 Source Loss=0.11516, Discrepancy Loss=0.00125
# Epoch: 53/100 [400/469]: C1 Source Loss =0.11017, C2 Source Loss=0.10801, Discrepancy Loss=0.00166
#
# Test: Accuracy on MNIST: 95% Accuracy on SVHN train: 88% Accuracy on SVHN test: 87%
#
# Epoch: 54/100 [100/469]: C1 Source Loss =0.04596, C2 Source Loss=0.04300, Discrepancy Loss=0.00112
# Epoch: 54/100 [200/469]: C1 Source Loss =0.07364, C2 Source Loss=0.07694, Discrepancy Loss=0.00104
# Epoch: 54/100 [300/469]: C1 Source Loss =0.05310, C2 Source Loss=0.05318, Discrepancy Loss=0.00079
# Epoch: 54/100 [400/469]: C1 Source Loss =0.05503, C2 Source Loss=0.05369, Discrepancy Loss=0.00085
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 89% Accuracy on SVHN test: 87%
#
# Epoch: 55/100 [100/469]: C1 Source Loss =0.01980, C2 Source Loss=0.02055, Discrepancy Loss=0.00083
# Epoch: 55/100 [200/469]: C1 Source Loss =0.03313, C2 Source Loss=0.03538, Discrepancy Loss=0.00124
# Epoch: 55/100 [300/469]: C1 Source Loss =0.11562, C2 Source Loss=0.11491, Discrepancy Loss=0.00233
# Epoch: 55/100 [400/469]: C1 Source Loss =0.03509, C2 Source Loss=0.03599, Discrepancy Loss=0.00106
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 92% Accuracy on SVHN test: 89%
#
# Epoch: 56/100 [100/469]: C1 Source Loss =0.01615, C2 Source Loss=0.01620, Discrepancy Loss=0.00097
# Epoch: 56/100 [200/469]: C1 Source Loss =0.04385, C2 Source Loss=0.04324, Discrepancy Loss=0.00081
# Epoch: 56/100 [300/469]: C1 Source Loss =0.06906, C2 Source Loss=0.07257, Discrepancy Loss=0.00102
# Epoch: 56/100 [400/469]: C1 Source Loss =0.07144, C2 Source Loss=0.07380, Discrepancy Loss=0.00162
#
# Test: Accuracy on MNIST: 95% Accuracy on SVHN train: 86% Accuracy on SVHN test: 85%
#
# Epoch: 57/100 [100/469]: C1 Source Loss =0.14723, C2 Source Loss=0.14486, Discrepancy Loss=0.00099
# Epoch: 57/100 [200/469]: C1 Source Loss =0.04617, C2 Source Loss=0.04188, Discrepancy Loss=0.00162
# Epoch: 57/100 [300/469]: C1 Source Loss =0.14116, C2 Source Loss=0.14043, Discrepancy Loss=0.00120
# Epoch: 57/100 [400/469]: C1 Source Loss =0.05283, C2 Source Loss=0.05494, Discrepancy Loss=0.00118
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 89% Accuracy on SVHN test: 87%
#
# Epoch: 58/100 [100/469]: C1 Source Loss =0.07324, C2 Source Loss=0.07645, Discrepancy Loss=0.00074
# Epoch: 58/100 [200/469]: C1 Source Loss =0.05447, C2 Source Loss=0.05268, Discrepancy Loss=0.00052
# Epoch: 58/100 [300/469]: C1 Source Loss =0.09509, C2 Source Loss=0.08911, Discrepancy Loss=0.00102
# Epoch: 58/100 [400/469]: C1 Source Loss =0.16646, C2 Source Loss=0.16638, Discrepancy Loss=0.00235
#
# Test: Accuracy on MNIST: 95% Accuracy on SVHN train: 88% Accuracy on SVHN test: 86%
#
# Epoch: 59/100 [100/469]: C1 Source Loss =0.02395, C2 Source Loss=0.02402, Discrepancy Loss=0.00166
# Epoch: 59/100 [200/469]: C1 Source Loss =0.07473, C2 Source Loss=0.07841, Discrepancy Loss=0.00104
# Epoch: 59/100 [300/469]: C1 Source Loss =0.06659, C2 Source Loss=0.06434, Discrepancy Loss=0.00064
# Epoch: 59/100 [400/469]: C1 Source Loss =0.15496, C2 Source Loss=0.14982, Discrepancy Loss=0.00159
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 90% Accuracy on SVHN test: 86%
#
# Epoch: 60/100 [100/469]: C1 Source Loss =0.02227, C2 Source Loss=0.02023, Discrepancy Loss=0.00067
# Epoch: 60/100 [200/469]: C1 Source Loss =0.07148, C2 Source Loss=0.07386, Discrepancy Loss=0.00148
# Epoch: 60/100 [300/469]: C1 Source Loss =0.02846, C2 Source Loss=0.02886, Discrepancy Loss=0.00100
# Epoch: 60/100 [400/469]: C1 Source Loss =0.03859, C2 Source Loss=0.04027, Discrepancy Loss=0.00117
#
# Test: Accuracy on MNIST: 95% Accuracy on SVHN train: 85% Accuracy on SVHN test: 84%
#
# Epoch: 61/100 [100/469]: C1 Source Loss =0.02519, C2 Source Loss=0.02643, Discrepancy Loss=0.00103
# Epoch: 61/100 [200/469]: C1 Source Loss =0.05037, C2 Source Loss=0.04638, Discrepancy Loss=0.00124
# Epoch: 61/100 [300/469]: C1 Source Loss =0.07745, C2 Source Loss=0.07873, Discrepancy Loss=0.00146
# Epoch: 61/100 [400/469]: C1 Source Loss =0.01763, C2 Source Loss=0.01753, Discrepancy Loss=0.00089
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 89% Accuracy on SVHN test: 86%
#
# Epoch: 62/100 [100/469]: C1 Source Loss =0.05005, C2 Source Loss=0.05002, Discrepancy Loss=0.00080
# Epoch: 62/100 [200/469]: C1 Source Loss =0.08086, C2 Source Loss=0.08114, Discrepancy Loss=0.00143
# Epoch: 62/100 [300/469]: C1 Source Loss =0.02420, C2 Source Loss=0.02540, Discrepancy Loss=0.00203
# Epoch: 62/100 [400/469]: C1 Source Loss =0.03984, C2 Source Loss=0.03834, Discrepancy Loss=0.00085
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 90% Accuracy on SVHN test: 88%
#
# Epoch: 63/100 [100/469]: C1 Source Loss =0.06033, C2 Source Loss=0.05836, Discrepancy Loss=0.00120
# Epoch: 63/100 [200/469]: C1 Source Loss =0.05448, C2 Source Loss=0.05165, Discrepancy Loss=0.00113
# Epoch: 63/100 [300/469]: C1 Source Loss =0.08051, C2 Source Loss=0.08400, Discrepancy Loss=0.00099
# Epoch: 63/100 [400/469]: C1 Source Loss =0.06054, C2 Source Loss=0.06309, Discrepancy Loss=0.00147
#
# Test: Accuracy on MNIST: 95% Accuracy on SVHN train: 89% Accuracy on SVHN test: 86%
#
# Epoch: 64/100 [100/469]: C1 Source Loss =0.10097, C2 Source Loss=0.09784, Discrepancy Loss=0.00098
# Epoch: 64/100 [200/469]: C1 Source Loss =0.08145, C2 Source Loss=0.07629, Discrepancy Loss=0.00083
# Epoch: 64/100 [300/469]: C1 Source Loss =0.07334, C2 Source Loss=0.07311, Discrepancy Loss=0.00135
# Epoch: 64/100 [400/469]: C1 Source Loss =0.07249, C2 Source Loss=0.06863, Discrepancy Loss=0.00151
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 89% Accuracy on SVHN test: 87%
#
# Epoch: 65/100 [100/469]: C1 Source Loss =0.08795, C2 Source Loss=0.08609, Discrepancy Loss=0.00136
# Epoch: 65/100 [200/469]: C1 Source Loss =0.02776, C2 Source Loss=0.03005, Discrepancy Loss=0.00138
# Epoch: 65/100 [300/469]: C1 Source Loss =0.04151, C2 Source Loss=0.03805, Discrepancy Loss=0.00137
# Epoch: 65/100 [400/469]: C1 Source Loss =0.11110, C2 Source Loss=0.11002, Discrepancy Loss=0.00128
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 88% Accuracy on SVHN test: 85%
#
# Epoch: 66/100 [100/469]: C1 Source Loss =0.05639, C2 Source Loss=0.05348, Discrepancy Loss=0.00104
# Epoch: 66/100 [200/469]: C1 Source Loss =0.07157, C2 Source Loss=0.07215, Discrepancy Loss=0.00124
# Epoch: 66/100 [300/469]: C1 Source Loss =0.17185, C2 Source Loss=0.17342, Discrepancy Loss=0.00092
# Epoch: 66/100 [400/469]: C1 Source Loss =0.02020, C2 Source Loss=0.01982, Discrepancy Loss=0.00130
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 91% Accuracy on SVHN test: 88%
#
# Epoch: 67/100 [100/469]: C1 Source Loss =0.05454, C2 Source Loss=0.05305, Discrepancy Loss=0.00113
# Epoch: 67/100 [200/469]: C1 Source Loss =0.01791, C2 Source Loss=0.01610, Discrepancy Loss=0.00123
# Epoch: 67/100 [300/469]: C1 Source Loss =0.03241, C2 Source Loss=0.03343, Discrepancy Loss=0.00084
# Epoch: 67/100 [400/469]: C1 Source Loss =0.04103, C2 Source Loss=0.04145, Discrepancy Loss=0.00143
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 91% Accuracy on SVHN test: 88%
#
# Epoch: 68/100 [100/469]: C1 Source Loss =0.04437, C2 Source Loss=0.04570, Discrepancy Loss=0.00116
# Epoch: 68/100 [200/469]: C1 Source Loss =0.04494, C2 Source Loss=0.04168, Discrepancy Loss=0.00096
# Epoch: 68/100 [300/469]: C1 Source Loss =0.03949, C2 Source Loss=0.04298, Discrepancy Loss=0.00115
# Epoch: 68/100 [400/469]: C1 Source Loss =0.10973, C2 Source Loss=0.10698, Discrepancy Loss=0.00234
#
# Test: Accuracy on MNIST: 95% Accuracy on SVHN train: 86% Accuracy on SVHN test: 84%
#
# Epoch: 69/100 [100/469]: C1 Source Loss =0.04455, C2 Source Loss=0.04755, Discrepancy Loss=0.00154
# Epoch: 69/100 [200/469]: C1 Source Loss =0.05130, C2 Source Loss=0.04889, Discrepancy Loss=0.00110
# Epoch: 69/100 [300/469]: C1 Source Loss =0.06883, C2 Source Loss=0.07187, Discrepancy Loss=0.00080
# Epoch: 69/100 [400/469]: C1 Source Loss =0.07625, C2 Source Loss=0.07484, Discrepancy Loss=0.00091
#
# Test: Accuracy on MNIST: 95% Accuracy on SVHN train: 91% Accuracy on SVHN test: 88%
#
# Epoch: 70/100 [100/469]: C1 Source Loss =0.05339, C2 Source Loss=0.05849, Discrepancy Loss=0.00087
# Epoch: 70/100 [200/469]: C1 Source Loss =0.01343, C2 Source Loss=0.01345, Discrepancy Loss=0.00069
# Epoch: 70/100 [300/469]: C1 Source Loss =0.04981, C2 Source Loss=0.05052, Discrepancy Loss=0.00094
# Epoch: 70/100 [400/469]: C1 Source Loss =0.05192, C2 Source Loss=0.05229, Discrepancy Loss=0.00093
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 89% Accuracy on SVHN test: 87%
#
# Epoch: 71/100 [100/469]: C1 Source Loss =0.02241, C2 Source Loss=0.01858, Discrepancy Loss=0.00178
# Epoch: 71/100 [200/469]: C1 Source Loss =0.10315, C2 Source Loss=0.10036, Discrepancy Loss=0.00164
# Epoch: 71/100 [300/469]: C1 Source Loss =0.04392, C2 Source Loss=0.04281, Discrepancy Loss=0.00100
# Epoch: 71/100 [400/469]: C1 Source Loss =0.07905, C2 Source Loss=0.08047, Discrepancy Loss=0.00114
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 88% Accuracy on SVHN test: 87%
#
# Epoch: 72/100 [100/469]: C1 Source Loss =0.01247, C2 Source Loss=0.01391, Discrepancy Loss=0.00105
# Epoch: 72/100 [200/469]: C1 Source Loss =0.04765, C2 Source Loss=0.04752, Discrepancy Loss=0.00161
# Epoch: 72/100 [300/469]: C1 Source Loss =0.06754, C2 Source Loss=0.07148, Discrepancy Loss=0.00113
# Epoch: 72/100 [400/469]: C1 Source Loss =0.08869, C2 Source Loss=0.08896, Discrepancy Loss=0.00124
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 85% Accuracy on SVHN test: 84%
#
# Epoch: 73/100 [100/469]: C1 Source Loss =0.09161, C2 Source Loss=0.09014, Discrepancy Loss=0.00127
# Epoch: 73/100 [200/469]: C1 Source Loss =0.10324, C2 Source Loss=0.09997, Discrepancy Loss=0.00091
# Epoch: 73/100 [300/469]: C1 Source Loss =0.12321, C2 Source Loss=0.12306, Discrepancy Loss=0.00097
# Epoch: 73/100 [400/469]: C1 Source Loss =0.06157, C2 Source Loss=0.06020, Discrepancy Loss=0.00159
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 89% Accuracy on SVHN test: 87%
#
# Epoch: 74/100 [100/469]: C1 Source Loss =0.08706, C2 Source Loss=0.08736, Discrepancy Loss=0.00119
# Epoch: 74/100 [200/469]: C1 Source Loss =0.08885, C2 Source Loss=0.08653, Discrepancy Loss=0.00125
# Epoch: 74/100 [300/469]: C1 Source Loss =0.08018, C2 Source Loss=0.07893, Discrepancy Loss=0.00155
# Epoch: 74/100 [400/469]: C1 Source Loss =0.05873, C2 Source Loss=0.06052, Discrepancy Loss=0.00111
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 87% Accuracy on SVHN test: 86%
#
# Epoch: 75/100 [100/469]: C1 Source Loss =0.08890, C2 Source Loss=0.08756, Discrepancy Loss=0.00150
# Epoch: 75/100 [200/469]: C1 Source Loss =0.03868, C2 Source Loss=0.04228, Discrepancy Loss=0.00150
# Epoch: 75/100 [300/469]: C1 Source Loss =0.03818, C2 Source Loss=0.03646, Discrepancy Loss=0.00099
# Epoch: 75/100 [400/469]: C1 Source Loss =0.12240, C2 Source Loss=0.12251, Discrepancy Loss=0.00129
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 93% Accuracy on SVHN test: 89%
#
# Epoch: 76/100 [100/469]: C1 Source Loss =0.07916, C2 Source Loss=0.07957, Discrepancy Loss=0.00131
# Epoch: 76/100 [200/469]: C1 Source Loss =0.07149, C2 Source Loss=0.07227, Discrepancy Loss=0.00101
# Epoch: 76/100 [300/469]: C1 Source Loss =0.05405, C2 Source Loss=0.05560, Discrepancy Loss=0.00084
# Epoch: 76/100 [400/469]: C1 Source Loss =0.05185, C2 Source Loss=0.05157, Discrepancy Loss=0.00084
#
# Test: Accuracy on MNIST: 95% Accuracy on SVHN train: 90% Accuracy on SVHN test: 88%
#
# Epoch: 77/100 [100/469]: C1 Source Loss =0.04372, C2 Source Loss=0.04497, Discrepancy Loss=0.00107
# Epoch: 77/100 [200/469]: C1 Source Loss =0.06535, C2 Source Loss=0.06496, Discrepancy Loss=0.00166
# Epoch: 77/100 [300/469]: C1 Source Loss =0.04507, C2 Source Loss=0.04789, Discrepancy Loss=0.00070
# Epoch: 77/100 [400/469]: C1 Source Loss =0.01366, C2 Source Loss=0.01234, Discrepancy Loss=0.00119
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 87% Accuracy on SVHN test: 85%
#
# Epoch: 78/100 [100/469]: C1 Source Loss =0.03777, C2 Source Loss=0.03579, Discrepancy Loss=0.00115
# Epoch: 78/100 [200/469]: C1 Source Loss =0.03335, C2 Source Loss=0.03326, Discrepancy Loss=0.00097
# Epoch: 78/100 [300/469]: C1 Source Loss =0.06535, C2 Source Loss=0.06511, Discrepancy Loss=0.00075
# Epoch: 78/100 [400/469]: C1 Source Loss =0.06617, C2 Source Loss=0.06528, Discrepancy Loss=0.00108
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 86% Accuracy on SVHN test: 84%
#
# Epoch: 79/100 [100/469]: C1 Source Loss =0.06156, C2 Source Loss=0.06260, Discrepancy Loss=0.00066
# Epoch: 79/100 [200/469]: C1 Source Loss =0.12417, C2 Source Loss=0.12343, Discrepancy Loss=0.00156
# Epoch: 79/100 [300/469]: C1 Source Loss =0.04522, C2 Source Loss=0.04753, Discrepancy Loss=0.00087
# Epoch: 79/100 [400/469]: C1 Source Loss =0.05801, C2 Source Loss=0.05666, Discrepancy Loss=0.00158
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 90% Accuracy on SVHN test: 88%
#
# Epoch: 80/100 [100/469]: C1 Source Loss =0.06437, C2 Source Loss=0.06420, Discrepancy Loss=0.00087
# Epoch: 80/100 [200/469]: C1 Source Loss =0.08390, C2 Source Loss=0.08172, Discrepancy Loss=0.00069
# Epoch: 80/100 [300/469]: C1 Source Loss =0.06117, C2 Source Loss=0.06065, Discrepancy Loss=0.00126
# Epoch: 80/100 [400/469]: C1 Source Loss =0.03260, C2 Source Loss=0.03040, Discrepancy Loss=0.00087
#
# Test: Accuracy on MNIST: 95% Accuracy on SVHN train: 89% Accuracy on SVHN test: 87%
#
# Epoch: 81/100 [100/469]: C1 Source Loss =0.03562, C2 Source Loss=0.03725, Discrepancy Loss=0.00142
# Epoch: 81/100 [200/469]: C1 Source Loss =0.09273, C2 Source Loss=0.09594, Discrepancy Loss=0.00110
# Epoch: 81/100 [300/469]: C1 Source Loss =0.02292, C2 Source Loss=0.02432, Discrepancy Loss=0.00086
# Epoch: 81/100 [400/469]: C1 Source Loss =0.12045, C2 Source Loss=0.11950, Discrepancy Loss=0.00089
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 88% Accuracy on SVHN test: 86%
#
# Epoch: 82/100 [100/469]: C1 Source Loss =0.03501, C2 Source Loss=0.03514, Discrepancy Loss=0.00178
# Epoch: 82/100 [200/469]: C1 Source Loss =0.05459, C2 Source Loss=0.05651, Discrepancy Loss=0.00134
# Epoch: 82/100 [300/469]: C1 Source Loss =0.06416, C2 Source Loss=0.06471, Discrepancy Loss=0.00189
# Epoch: 82/100 [400/469]: C1 Source Loss =0.07690, C2 Source Loss=0.07668, Discrepancy Loss=0.00146
#
# Test: Accuracy on MNIST: 95% Accuracy on SVHN train: 88% Accuracy on SVHN test: 86%
#
# Epoch: 83/100 [100/469]: C1 Source Loss =0.03658, C2 Source Loss=0.03944, Discrepancy Loss=0.00124
# Epoch: 83/100 [200/469]: C1 Source Loss =0.03919, C2 Source Loss=0.03706, Discrepancy Loss=0.00064
# Epoch: 83/100 [300/469]: C1 Source Loss =0.06088, C2 Source Loss=0.06161, Discrepancy Loss=0.00070
# Epoch: 83/100 [400/469]: C1 Source Loss =0.08709, C2 Source Loss=0.08957, Discrepancy Loss=0.00144
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 86% Accuracy on SVHN test: 84%
#
# Epoch: 84/100 [100/469]: C1 Source Loss =0.03367, C2 Source Loss=0.02902, Discrepancy Loss=0.00073
# Epoch: 84/100 [200/469]: C1 Source Loss =0.07908, C2 Source Loss=0.07866, Discrepancy Loss=0.00098
# Epoch: 84/100 [300/469]: C1 Source Loss =0.01551, C2 Source Loss=0.01574, Discrepancy Loss=0.00105
# Epoch: 84/100 [400/469]: C1 Source Loss =0.08628, C2 Source Loss=0.08535, Discrepancy Loss=0.00085
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 85% Accuracy on SVHN test: 84%
#
# Epoch: 85/100 [100/469]: C1 Source Loss =0.03844, C2 Source Loss=0.03852, Discrepancy Loss=0.00158
# Epoch: 85/100 [200/469]: C1 Source Loss =0.02978, C2 Source Loss=0.02986, Discrepancy Loss=0.00102
# Epoch: 85/100 [300/469]: C1 Source Loss =0.01758, C2 Source Loss=0.01665, Discrepancy Loss=0.00086
# Epoch: 85/100 [400/469]: C1 Source Loss =0.08337, C2 Source Loss=0.07606, Discrepancy Loss=0.00051
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 90% Accuracy on SVHN test: 88%
#
# Epoch: 86/100 [100/469]: C1 Source Loss =0.04222, C2 Source Loss=0.04279, Discrepancy Loss=0.00110
# Epoch: 86/100 [200/469]: C1 Source Loss =0.05571, C2 Source Loss=0.05792, Discrepancy Loss=0.00143
# Epoch: 86/100 [300/469]: C1 Source Loss =0.07433, C2 Source Loss=0.07262, Discrepancy Loss=0.00099
# Epoch: 86/100 [400/469]: C1 Source Loss =0.03346, C2 Source Loss=0.03314, Discrepancy Loss=0.00111
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 89% Accuracy on SVHN test: 87%
#
# Epoch: 87/100 [100/469]: C1 Source Loss =0.07216, C2 Source Loss=0.07058, Discrepancy Loss=0.00099
# Epoch: 87/100 [200/469]: C1 Source Loss =0.04262, C2 Source Loss=0.04185, Discrepancy Loss=0.00078
# Epoch: 87/100 [300/469]: C1 Source Loss =0.04097, C2 Source Loss=0.04037, Discrepancy Loss=0.00108
# Epoch: 87/100 [400/469]: C1 Source Loss =0.04625, C2 Source Loss=0.04341, Discrepancy Loss=0.00073
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 87% Accuracy on SVHN test: 85%
#
# Epoch: 88/100 [100/469]: C1 Source Loss =0.06713, C2 Source Loss=0.06998, Discrepancy Loss=0.00093
# Epoch: 88/100 [200/469]: C1 Source Loss =0.06505, C2 Source Loss=0.06510, Discrepancy Loss=0.00087
# Epoch: 88/100 [300/469]: C1 Source Loss =0.08300, C2 Source Loss=0.08348, Discrepancy Loss=0.00136
# Epoch: 88/100 [400/469]: C1 Source Loss =0.04338, C2 Source Loss=0.04402, Discrepancy Loss=0.00117
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 90% Accuracy on SVHN test: 88%
#
# Epoch: 89/100 [100/469]: C1 Source Loss =0.02601, C2 Source Loss=0.02768, Discrepancy Loss=0.00052
# Epoch: 89/100 [200/469]: C1 Source Loss =0.06162, C2 Source Loss=0.06287, Discrepancy Loss=0.00071
# Epoch: 89/100 [300/469]: C1 Source Loss =0.03214, C2 Source Loss=0.03160, Discrepancy Loss=0.00078
# Epoch: 89/100 [400/469]: C1 Source Loss =0.06160, C2 Source Loss=0.05528, Discrepancy Loss=0.00082
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 89% Accuracy on SVHN test: 86%
#
# Epoch: 90/100 [100/469]: C1 Source Loss =0.05488, C2 Source Loss=0.05329, Discrepancy Loss=0.00140
# Epoch: 90/100 [200/469]: C1 Source Loss =0.05175, C2 Source Loss=0.05471, Discrepancy Loss=0.00123
# Epoch: 90/100 [300/469]: C1 Source Loss =0.02839, C2 Source Loss=0.02541, Discrepancy Loss=0.00122
# Epoch: 90/100 [400/469]: C1 Source Loss =0.07053, C2 Source Loss=0.07364, Discrepancy Loss=0.00074
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 89% Accuracy on SVHN test: 87%
#
# Epoch: 91/100 [100/469]: C1 Source Loss =0.04802, C2 Source Loss=0.04881, Discrepancy Loss=0.00096
# Epoch: 91/100 [200/469]: C1 Source Loss =0.03427, C2 Source Loss=0.03325, Discrepancy Loss=0.00130
# Epoch: 91/100 [300/469]: C1 Source Loss =0.10567, C2 Source Loss=0.10535, Discrepancy Loss=0.00169
# Epoch: 91/100 [400/469]: C1 Source Loss =0.07567, C2 Source Loss=0.07232, Discrepancy Loss=0.00079
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 84% Accuracy on SVHN test: 83%
#
# Epoch: 92/100 [100/469]: C1 Source Loss =0.05255, C2 Source Loss=0.04844, Discrepancy Loss=0.00108
# Epoch: 92/100 [200/469]: C1 Source Loss =0.04518, C2 Source Loss=0.04548, Discrepancy Loss=0.00123
# Epoch: 92/100 [300/469]: C1 Source Loss =0.06620, C2 Source Loss=0.06239, Discrepancy Loss=0.00066
# Epoch: 92/100 [400/469]: C1 Source Loss =0.08969, C2 Source Loss=0.08949, Discrepancy Loss=0.00078
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 83% Accuracy on SVHN test: 82%
#
# Epoch: 93/100 [100/469]: C1 Source Loss =0.04252, C2 Source Loss=0.04033, Discrepancy Loss=0.00103
# Epoch: 93/100 [200/469]: C1 Source Loss =0.02276, C2 Source Loss=0.02321, Discrepancy Loss=0.00057
# Epoch: 93/100 [300/469]: C1 Source Loss =0.05366, C2 Source Loss=0.05196, Discrepancy Loss=0.00105
# Epoch: 93/100 [400/469]: C1 Source Loss =0.05333, C2 Source Loss=0.05439, Discrepancy Loss=0.00121
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 89% Accuracy on SVHN test: 87%
#
# Epoch: 94/100 [100/469]: C1 Source Loss =0.05803, C2 Source Loss=0.05984, Discrepancy Loss=0.00111
# Epoch: 94/100 [200/469]: C1 Source Loss =0.02906, C2 Source Loss=0.02694, Discrepancy Loss=0.00134
# Epoch: 94/100 [300/469]: C1 Source Loss =0.08595, C2 Source Loss=0.08783, Discrepancy Loss=0.00164
# Epoch: 94/100 [400/469]: C1 Source Loss =0.08520, C2 Source Loss=0.08029, Discrepancy Loss=0.00147
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 87% Accuracy on SVHN test: 85%
#
# Epoch: 95/100 [100/469]: C1 Source Loss =0.04525, C2 Source Loss=0.04644, Discrepancy Loss=0.00080
# Epoch: 95/100 [200/469]: C1 Source Loss =0.04970, C2 Source Loss=0.04931, Discrepancy Loss=0.00128
# Epoch: 95/100 [300/469]: C1 Source Loss =0.07331, C2 Source Loss=0.07499, Discrepancy Loss=0.00081
# Epoch: 95/100 [400/469]: C1 Source Loss =0.05402, C2 Source Loss=0.05378, Discrepancy Loss=0.00144
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 90% Accuracy on SVHN test: 88%
#
# Epoch: 96/100 [100/469]: C1 Source Loss =0.02235, C2 Source Loss=0.02339, Discrepancy Loss=0.00110
# Epoch: 96/100 [200/469]: C1 Source Loss =0.03398, C2 Source Loss=0.03399, Discrepancy Loss=0.00139
# Epoch: 96/100 [300/469]: C1 Source Loss =0.04860, C2 Source Loss=0.05082, Discrepancy Loss=0.00084
# Epoch: 96/100 [400/469]: C1 Source Loss =0.06596, C2 Source Loss=0.06515, Discrepancy Loss=0.00138
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 88% Accuracy on SVHN test: 87%
#
# Epoch: 97/100 [100/469]: C1 Source Loss =0.03615, C2 Source Loss=0.03715, Discrepancy Loss=0.00050
# Epoch: 97/100 [200/469]: C1 Source Loss =0.07190, C2 Source Loss=0.07302, Discrepancy Loss=0.00076
# Epoch: 97/100 [300/469]: C1 Source Loss =0.07988, C2 Source Loss=0.08678, Discrepancy Loss=0.00122
# Epoch: 97/100 [400/469]: C1 Source Loss =0.08315, C2 Source Loss=0.08221, Discrepancy Loss=0.00106
#
# Test: Accuracy on MNIST: 95% Accuracy on SVHN train: 85% Accuracy on SVHN test: 82%
#
# Epoch: 98/100 [100/469]: C1 Source Loss =0.03527, C2 Source Loss=0.03574, Discrepancy Loss=0.00146
# Epoch: 98/100 [200/469]: C1 Source Loss =0.06334, C2 Source Loss=0.06707, Discrepancy Loss=0.00094
# Epoch: 98/100 [300/469]: C1 Source Loss =0.11701, C2 Source Loss=0.11957, Discrepancy Loss=0.00067
# Epoch: 98/100 [400/469]: C1 Source Loss =0.05298, C2 Source Loss=0.05478, Discrepancy Loss=0.00172
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 89% Accuracy on SVHN test: 87%
#
# Epoch: 99/100 [100/469]: C1 Source Loss =0.03058, C2 Source Loss=0.02851, Discrepancy Loss=0.00135
# Epoch: 99/100 [200/469]: C1 Source Loss =0.03433, C2 Source Loss=0.03548, Discrepancy Loss=0.00099
# Epoch: 99/100 [300/469]: C1 Source Loss =0.07651, C2 Source Loss=0.07591, Discrepancy Loss=0.00069
# Epoch: 99/100 [400/469]: C1 Source Loss =0.05498, C2 Source Loss=0.05631, Discrepancy Loss=0.00112
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 90% Accuracy on SVHN test: 87%
#
# Epoch: 100/100 [100/469]: C1 Source Loss =0.05620, C2 Source Loss=0.05431, Discrepancy Loss=0.00066
# Epoch: 100/100 [200/469]: C1 Source Loss =0.03776, C2 Source Loss=0.03658, Discrepancy Loss=0.00103
# Epoch: 100/100 [300/469]: C1 Source Loss =0.05348, C2 Source Loss=0.05483, Discrepancy Loss=0.00077
# Epoch: 100/100 [400/469]: C1 Source Loss =0.09128, C2 Source Loss=0.08652, Discrepancy Loss=0.00105
#
# Test: Accuracy on MNIST: 96% Accuracy on SVHN train: 87% Accuracy on SVHN test: 86%

# %% [markdown]
# ## t-SNE Embeddings visualization

# %% [markdown]
# Graph of embeddings was built using TensorBoard
#
# Before DA (Pre-trained on SVHN)                  |  After DA
# :-----------------------------------------------:|:-------------------------:
# ![](imgs/t-SNE_bfDA.png)                         |  ![](imgs/t-SNE_MCD.jpg)
